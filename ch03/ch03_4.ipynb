# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img = cv2.imread('/content/gdrive/My Drive/Images/lena256.jpg')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gImg1 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gImg1.shape)
plt.imshow(gImg1, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-55eb12e86b8e> in <cell line: 1>()
# ----> 1 img = cv2.imread('/content/gdrive/My Drive/Images/rice.bmp')
#       2 RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       3 gImg1 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
#       4 print(gImg1.shape)
#       5 plt.imshow(gImg1, cmap='gray')
#
# NameError: name 'cv2' is not defined

# %%
gOutImg = np.zeros((gImg1.shape[0], gImg1.shape[1]))

# %%
for h in range(0, gImg1.shape[0]):
  for w in range(0, gImg1.shape[1]):
    val = gImg1[h,w] % 64
    val = val * 4
    gOutImg[h,w] = val

#plt.imshow(gOutImg, cmap='gray')
cv2_imshow(gOutImg)
# Out:
# <PIL.Image.Image image mode=L size=360x360>

# %%
equalVal = 200
width = 5

min = equalVal - width
max = equalVal + width

# %%
for h in range(0, gImg1.shape[0]):
  for w in range(0, gImg1.shape[1]):
    if(gImg1[h,w] > min and gImg1[h,w] < max):
      gOutImg[h,w] = 0
    else:
      gOutImg[h,w] = gImg[h,w]

plt.imshow(gOutImg, cmap='gray')

# %%
for h in range(0, gImg1.shape[0]):
  for w in range(0, gImg1.shape[1]):
    val = 255*(gImg1[h,w]/128-1)*(gImg1[h,w]/128-1)
    gOutImg[h,w] = val

#plt.imshow(gOutImg, cmap='gray')
cv2_imshow(gOutImg)
# Out:
# <PIL.Image.Image image mode=L size=360x360>

# %%
planeNumber = 1
planeValue = 1

for i in  range(planeNumber-1):
  planeValue = planeValue * 2

# %%
for h in range(0, gImg1.shape[0]):
  for w in range(0, gImg1.shape[1]):
    imVal = (int)(gImg1[h,w] /planeValue)
    if(imVal % 2 == 0):
      gOutImg[h,w] = 0
    else:
      gOutImg[h,w] = 255

#plt.imshow(gOutImg, cmap='gray')
cv2_imshow(gOutImg)
# Out:
# <PIL.Image.Image image mode=L size=360x360>

# %%
img = cv2.imread('/content/gdrive/My Drive/Images/circle.bmp')
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gImg2 = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2GRAY)
print(gImg2.shape)
plt.imshow(gImg2, cmap='gray')
# Out:
# (286, 322)

# %%
gWaterMarker = gImg1.copy()

for h in range(0, gImg1.shape[0]):
  for w in range(0, gImg1.shape[1]):
    imVal = gImg2[h,w]
    if(imVal > 128):
      if(gImg1[h,w] % 2 == 0):
        gWaterMarker[h,w] += 1
      else:
        if(gImg1[h,w] % 2 == 1):
          gWaterMarker[h,w] -= 1

cv2_imshow(gWaterMarker)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
planeNumber = 1
planeValue = 1

for i in  range(planeNumber-1):
  planeValue = planeValue * 2

# %%
for h in range(0, gWaterMarker.shape[0]):
  for w in range(0, gWaterMarker.shape[1]):
    imVal = (int)(gWaterMarker[h,w] /planeValue)
    if(imVal % 2 == 0):
      gOutImg[h,w] = 0
    else:
      gOutImg[h,w] = 255

#plt.imshow(gOutImg, cmap='gray')
cv2_imshow(gOutImg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %% [markdown]
# ??????????????
